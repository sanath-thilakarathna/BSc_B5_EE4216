# %%
print("EE7306 – Setup Verification Notebook")
print("This notebook checks Python, environment, and required libraries.")
# Out:
# EE7306 – Setup Verification Notebook
# This notebook checks Python, environment, and required libraries.

# %%
import sys

print("Python version:")
print(sys.version)

major, minor = sys.version_info[:2]
if major == 3 and minor == 10:
    print("✅ Python version is correct (3.10)")
else:
    print("❌ WARNING: Python version is NOT 3.10")
# Out:
# Python version:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]
# ✅ Python version is correct (3.10)

# %%
import sys
import os

print("Executable path:")
print(sys.executable)

print("\nCurrent working directory:")
print(os.getcwd())

print("\nIf this path contains 'ee4216', the correct environment is active.")
# Out:
# Executable path:
# c:\Users\sanat\anaconda3\envs\ee4216\python.exe
#
# Current working directory:
# d:\BSc_B5_EE4216\00_Setup
#
# If this path contains 'ee4216', the correct environment is active.

# %%
import numpy as np

a = np.array([[1, 2, 3],
              [4, 5, 6]])

print("NumPy array:")
print(a)
print("Shape:", a.shape)
print("Data type:", a.dtype)

print("✅ NumPy is working")
# Out:
# NumPy array:
# [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
# Data type: int64
# ✅ NumPy is working

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x, y)
plt.title("Matplotlib Test Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

print("✅ Matplotlib is working")
# Out:
# ✅ Matplotlib is working

# %%
import cv2

print("OpenCV version:")
print(cv2.__version__)

print("✅ OpenCV is installed correctly")
# Out:
# OpenCV version:
# 4.13.0
# ✅ OpenCV is installed correctly

# %%
# Create a simple grayscale image (100x100)
test_img = np.zeros((100, 100), dtype=np.uint8)
test_img[25:75, 25:75] = 255

print("Image shape:", test_img.shape)
print("Data type:", test_img.dtype)
# Out:
# Image shape: (100, 100)
# Data type: uint8

# %%
plt.imshow(test_img, cmap='gray')
plt.title("Test Image Display")
plt.axis('off')
plt.show()

print("✅ Image display works")
# Out:
# ✅ Image display works

# %%
# Apply Gaussian blur
blurred = cv2.GaussianBlur(test_img, (5, 5), 0)

plt.figure(figsize=(6,3))

plt.subplot(1,2,1)
plt.imshow(test_img, cmap='gray')
plt.title("Original")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(blurred, cmap='gray')
plt.title("Blurred")
plt.axis('off')

plt.show()

print("✅ OpenCV image processing works")
# Out:
# ✅ OpenCV image processing works

# %%
print("===================================")
print("SETUP CHECK COMPLETE")
print("If no errors appeared above:")
print("✅ Environment is correctly configured for EE7306")
print("===================================")
# Out:
# ...
# SETUP CHECK COMPLETE
# If no errors appeared above:
# ✅ Environment is correctly configured for EE7306
# ...
